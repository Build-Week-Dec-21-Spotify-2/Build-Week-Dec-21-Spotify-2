# %%
# Importing libraries 

import pandas as pd
import numpy as np
import json
import re 
import sys
import itertools
import pickle

from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.metrics.pairwise import cosine_similarity
from sklearn.preprocessing import MinMaxScaler
import matplotlib.pyplot as plt
from sklearn.neighbors import KDTree
from sklearn.neighbors import NearestNeighbors

import warnings
warnings.filterwarnings("ignore")

# %%
# Reading in and slimming down the scv file

df = pd.read_csv('app_data\spotify_track_features.csv')

#df = df.sample(n = 500000)

# %% [markdown]
# ## Doing some EDA

# %%
df.shape
# Out:
# (1758, 18)

# %%
df.isnull().sum().sum()
# Out:
# 0

# %%
df.head()
# Out:
#    Unnamed: 0                             track_name                track_id  \
# 0           0  M' Manc (con Geolier & Sfera Ebbasta)  0MLu1cFYL4ikdRTdasCQT9
# 1           1                         Indispensabile  6StZfpZWT9IwyfdqqBj5k2
# 2           2                              Scorpione  0vkFcZZXyV8gnZGuCJ442S
# 3           3                                 Nebula  4mfm0COGySDHbPKCJr9jzJ
# 4           4                       Dreamer nos vies  39ypweDsKFtqN2iTcmtuG5
#
#                                   artists  \
# 0  ['Shablo', 'Geolier', 'Sfera Ebbasta']
# 1                        ['Davide Rossi']
# 2       ['Donzell*', 'Giuggi Situazione']
# 3                                ['Dial']
# 4                   ['RCZ', 'Dreamy BOY']
#
#                                            artist_id  danceability  energy  \
# 0  ['6hkKbkZGvAXuvle2FhCnxy', '27LlKWxS3KXW7RRAxN...         0.703   0.704
# 1                         ['0wG1NVcTvpOjGKUnSVqetO']         0.659   0.718
# 2  ['4H866sUs33uCqVx5cIimGy', '6OPbhiNiFbkC2Hy9WN...         0.631   0.643
# 3                         ['0qZWeHRw63u15y7L0u7fyB']         0.457   0.513
# 4  ['6rR1ycLMVWsVuyms0ZwVjj', '7xjNlyVktCjfAwfLd5...         0.843   0.602
#
#    key  loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 0    6    -6.117     0       0.0641         0.048          0.000000    0.4100
# 1    1    -6.075     0       0.0372         0.089          0.000000    0.1340
# 2   11    -7.604     1       0.0454         0.755          0.000108    0.0906
# 3   10   -12.164     0       0.2710         0.266          0.000323    0.1080
# 4    5    -7.643     0       0.3600         0.766          0.000000    0.1080
#
#    valence    tempo  duration_ms  time_signature
# 0    0.725  139.933       180000               4
# 1    0.610  120.018       183843               4
# 2    0.285  160.029       174000               4
# 3    0.461  124.968       209816               4
# 4    0.696  120.114       162494               4

# %%
df['time_signature'].value_counts()
# Out:
# 4    1580
# 3     140
# 5      24
# 1      14
# Name: time_signature, dtype: int64

# %% [markdown]
# ## NLP and creating new columns

# %%
df['artists_upd_v1'] = df['artists'].apply(lambda x: re.findall(r"'([^']*)'", x))
df['artists_upd_v2'] = df['artists'].apply(lambda x: re.findall('\"(.*?)\"',x))
df['artists_upd'] = np.where(df['artists_upd_v1'].apply(lambda x: not x), df['artists_upd_v2'], df['artists_upd_v1'] )

# %%
#need to create my own song identifier because there are duplicates of the same song with different ids
df['artists_song'] = df.apply(lambda row: row['track_name'] + ' ' + 'by'+ ' ' + row['artists_upd'][0],axis = 1)

# %%
df.head()
# Out:
#    Unnamed: 0                track_id                                 artists  \
# 0           0  0MLu1cFYL4ikdRTdasCQT9  ['Shablo', 'Geolier', 'Sfera Ebbasta']
# 1           1  6StZfpZWT9IwyfdqqBj5k2                        ['Davide Rossi']
# 2           2  0vkFcZZXyV8gnZGuCJ442S       ['Donzell*', 'Giuggi Situazione']
# 3           3  4mfm0COGySDHbPKCJr9jzJ                                ['Dial']
# 4           4  39ypweDsKFtqN2iTcmtuG5                   ['RCZ', 'Dreamy BOY']
#
#                                            artist_id  danceability  energy  \
# 0  ['6hkKbkZGvAXuvle2FhCnxy', '27LlKWxS3KXW7RRAxN...         0.703   0.704
# 1                         ['0wG1NVcTvpOjGKUnSVqetO']         0.659   0.718
# 2  ['4H866sUs33uCqVx5cIimGy', '6OPbhiNiFbkC2Hy9WN...         0.631   0.643
# 3                         ['0qZWeHRw63u15y7L0u7fyB']         0.457   0.513
# 4  ['6rR1ycLMVWsVuyms0ZwVjj', '7xjNlyVktCjfAwfLd5...         0.843   0.602
#
#    key  loudness  mode  speechiness  acousticness  instrumentalness  liveness  \
# 0    6    -6.117     0       0.0641         0.048          0.000000    0.4100
# 1    1    -6.075     0       0.0372         0.089          0.000000    0.1340
# 2   11    -7.604     1       0.0454         0.755          0.000108    0.0906
# 3   10   -12.164     0       0.2710         0.266          0.000323    0.1080
# 4    5    -7.643     0       0.3600         0.766          0.000000    0.1080
#
#    valence    tempo  duration_ms  time_signature  \
# 0    0.725  139.933       180000               4
# 1    0.610  120.018       183843               4
# 2    0.285  160.029       174000               4
# 3    0.461  124.968       209816               4
# 4    0.696  120.114       162494               4
#
#                                       artists_song
# 0  M' Manc (con Geolier & Sfera Ebbasta) by Shablo
# 1                   Indispensabile by Davide Rossi
# 2                            Scorpione by Donzell*
# 3                                   Nebula by Dial
# 4                          Dreamer nos vies by RCZ

# %%
df['artists_song'][0]
# Out:
# "M' Manc (con Geolier & Sfera Ebbasta) by Shablo"

# %%
# Reduce columns to 13 to match the song features that Spotify API will return to us plus column with Song and Artist name 
cols_to_drop = [
        "Unnamed:",
        "track_id",
        "artists",
        "artist_id",
        "track_name",
        "artists_upd",
        "artists_upd_v2",
        "artists_upd_v1",
        
    ]
df = df.drop(cols_to_drop, axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_41004/3628475524.py in <module>
#       9
#      10     ]
# ---> 11 df = df.drop(cols_to_drop, axis=1)
#
# ~\.virtualenvs\Build-week-TLds1Bbz\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\.virtualenvs\Build-week-TLds1Bbz\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4904                 weight  1.0     0.8
#    4905         """
# -> 4906         return super().drop(
#    4907             labels=labels,
#    4908             axis=axis,
#
# ~\.virtualenvs\Build-week-TLds1Bbz\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4148         for axis, labels in axes.items():
#    4149             if labels is not None:
# -> 4150                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4151
#    4152         if inplace:
#
# ~\.virtualenvs\Build-week-TLds1Bbz\lib\site-packages\pandas\core\generic.py in _drop_axis(self, labels, axis, level, errors)
#    4183                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4184             else:
# -> 4185                 new_axis = axis.drop(labels, errors=errors)
#    4186             result = self.reindex(**{axis_name: new_axis})
#    4187
#
# ~\.virtualenvs\Build-week-TLds1Bbz\lib\site-packages\pandas\core\indexes\base.py in drop(self, labels, errors)
#    6015         if mask.any():
#    6016             if errors != "ignore":
# -> 6017                 raise KeyError(f"{labels[mask]} not found in axis")
#    6018             indexer = indexer[~mask]
#    6019         return self.delete(indexer)
#
# KeyError: "['Unnamed:' 'track_name' 'artists_upd' 'artists_upd_v2' 'artists_upd_v1'] not found in axis"

# %%
df.shape
# Out:
# (1758, 18)

# %%
# DF with song features that Spotify API will return
features = df.drop(columns='artists_song')

# %%
features
# Out:
#         danceability  energy  key  loudness  mode  speechiness  acousticness  \
# 879643         0.653  0.7430    8   -11.351     1       0.2080       0.55500
# 384519         0.396  0.1670    7   -16.559     1       0.0436       0.94600
# 185840         0.490  0.9890    0    -2.207     1       0.1130       0.05810
# 804809         0.545  0.5100    0    -9.776     1       0.0269       0.70400
# 901611         0.497  0.5410    0   -11.856     0       0.0592       0.73300
# ...              ...     ...  ...       ...   ...          ...           ...
# 489437         0.645  0.6380    0    -6.711     1       0.0249       0.05770
# 790945         0.762  0.8620    0    -7.458     1       0.0337       0.42000
# 978858         0.423  0.9900   10    -5.843     1       0.1530       0.00785
# 224852         0.149  0.0378    1   -26.347     1       0.0435       0.87900
# 498302         0.566  0.2770   11    -8.448     1       0.0261       0.72400
#
#         instrumentalness  liveness  valence    tempo  duration_ms  \
# 879643          0.000036     0.118   0.8160   78.343       319093
# 384519          0.262000     0.267   0.4870   90.502       306600
# 185840          0.000000     0.253   0.6580  103.550       121240
# 804809          0.041500     0.165   0.0818   97.026       200550
# 901611          0.043200     0.148   0.2820  160.863       202497
# ...                  ...       ...      ...      ...          ...
# 489437          0.002710     0.176   0.5010  128.911       311231
# 790945          0.037500     0.180   0.9200  128.182       220880
# 978858          0.000375     0.104   0.2320   97.171       422880
# 224852          0.880000     0.104   0.0328   86.375       601560
# 498302          0.000275     0.124   0.2930   87.059       263293
#
#         time_signature
# 879643             4.0
# 384519             4.0
# 185840             4.0
# 804809             4.0
# 901611             4.0
# ...                ...
# 489437             4.0
# 790945             4.0
# 978858             4.0
# 224852             4.0
# 498302             4.0
#
# [500000 rows x 13 columns]

# %%
# creating df with indexes and song by artist columns 
names = df[['artists_song']]

# %%
# Creating and fitting NearestNeighbors model
model = NearestNeighbors(n_neighbors=10, algorithm='brute')
model.fit(features)
# Out:
# NearestNeighbors(algorithm='brute', n_neighbors=10)

# %%
# indexes of recommended songs basen on features of the first song in our dataset
n_dist, n_ind = model.kneighbors(features.head(1))
ind = list(n_ind[0])

# %%
# 5 recommended songs
id_list = [1, 2, 3, 4, 5]
artist_song = []

for each in ind:
    artist_song.append(names.iloc[each]["artists_song"])

recommendations = list(zip(id_list, artist_song))

recommendations
# Out:
# [(1, 'Bailando by Los Sabrosos Del Merengue'),
#  (2, 'White Boots Marching In A Yellow Land by Eric Andersen'),
#  (3, 'White Boots Marching In A Yellow Land by Eric Andersen'),
#  (4, 'El Soul by Sean Jones'),
#  (5, 'UmbraStory by Longing For Orpheus')]

# %%
# Creating a csv
names.to_csv(r'song_artist.csv')

# %%
# Saving our trained model
pickle.dump(model, open('Spotify_model_new', 'wb'))
